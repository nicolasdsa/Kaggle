# %% [markdown]
# # 02 Features
#
# ## Objective
#
# Validate that the project feature-building step creates a usable set-level analytical dataset.

# %%
import pandas as pd

from projects.lego_database.src.dataset import build_processed_dataset

output_path = build_processed_dataset()
df = pd.read_csv(output_path)
df.head()

# %%
# TODO: extend this notebook with feature validation and new engineered features.
# Basic expected result for this objective:
# - confirm the processed dataset was generated successfully
# - inspect whether the main derived columns exist
# - verify that the dataset is already at set level and ready for analysis/modeling

feature_columns = [
    "set_num",
    "theme_name",
    "theme_depth",
    "inventory_count",
    "unique_parts",
    "unique_colors",
    "inventory_quantity",
    "complexity_class",
]

print(output_path)
print(df[feature_columns].head())
print(df[feature_columns].isna().sum())
